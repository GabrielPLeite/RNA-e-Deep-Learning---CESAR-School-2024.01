# %% [markdown]
# Primeiro Resultado ok
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aumentando o lr para 0.03 foi possivel chegar a um resultado ok em menos épocas
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Realizando algumas pesquisas, entendi que o numero de camadas interfere mais computacionalmente do que o numero de neuronios em uma camada, por isso, reduzi uma camada e aumentei os neuronios das remanescentes
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Contra intuitivamente, diminui o lr e obtive um resultado melhor em menos tempo  ![image.png](data:image/png;base64,...)

# %% [markdown]
# Diminui um neuronio de uma das camadas, e para chegar no resultado tive que voltar o lr para 0.03 e aumentar o ratio of traning to test para 70%  ![image.png](data:image/png;base64,...)

# %% [markdown]
# Por ultimo, consegui retirar mais um neuronio da ultima camada, chegando nesse resultado  ![image.png](data:image/png;base64,...)

# %% [markdown]
# Com esse dataset pude perceber a influencia de cada parâmetro na otimização do modelo, o numero de camadas e neuronios são os maiores potencializadores, porém são aqueles que exigem maior custo operacional.
